# %%
import librosa
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
x, sr = librosa.load('Anry.wav')
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
hop_length = 200 # samples per frame
onset_env = librosa.onset.onset_strength(x, sr=sr, hop_length=hop_length, n_fft=2048)
frames = range(len(onset_env))
t = librosa.frames_to_time(frames, sr=sr, hop_length=hop_length)
plt.plot(t, onset_env)
plt.xlim(0, t.max())
plt.ylim(0)
plt.xlabel('Time (sec)')
plt.title('Novelty Function')
# Out:
# C:\Users\dipte\AppData\Local\Temp\ipykernel_22796\401685584.py:2: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.2171618  -0.22971795
#  -0.28947657] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   onset_env = librosa.onset.onset_strength(x, sr=sr, hop_length=hop_length, n_fft=2048)
# Text(0.5, 1.0, 'Novelty Function')

# %%
import librosa.display
S = librosa.stft(onset_env, hop_length=1, n_fft=512)
fourier_tempogram = numpy.absolute(S)
librosa.display.specshow(fourier_tempogram, sr=sr, hop_length=hop_length, x_axis='time')

# %%
n0 = 100
n1 = 500
plt.plot(t[n0:n1], onset_env[n0:n1])
plt.xlim(t[n0], t[n1])
plt.xlabel('Time (sec)')
plt.title('Novelty Function')
# Out:
# Text(0.5, 1.0, 'Novelty Function')

# %%
tmp = numpy.log1p(onset_env[n0:n1])
r = librosa.autocorrelate(tmp)
plt.plot(t[:n1-n0], r)
plt.xlim(t[0], t[n1-n0])
plt.xlabel('Lag (sec)')
plt.ylim(0)
# Out:
# (0.0, 96.29940585240591)

# %%
plt.plot(60/t[:n1-n0], r)
plt.xlim(20, 200)
plt.xlabel('Tempo (BPM)')
plt.ylim(0)
# Out:
# C:\Users\dipte\AppData\Local\Temp\ipykernel_22796\1652656273.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(60/t[:n1-n0], r)
# (0.0, 90.3584666573518)

# %%
tempo = librosa.beat.tempo(x, sr=sr)
print(tempo)
# Out:
# [95.703125]
# C:\Users\dipte\AppData\Local\Temp\ipykernel_22796\1757904990.py:1: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.2171618  -0.22971795
#  -0.28947657] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   tempo = librosa.beat.tempo(x, sr=sr)

# %%
librosa.display.waveshow(x)
plt.vlines(beat_times, -1, 1, color='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 librosa.display.waveshow(x)
# ----> 2 plt.vlines(beat_times, -1, 1, color='r')
#
# NameError: name 'beat_times' is not defined

# %%
T = len(x)/float(sr)
seconds_per_beat = 60.0/tempo[0]
beat_times = numpy.arange(0, T, seconds_per_beat)
librosa.display.waveshow(x)
plt.vlines(beat_times, -1, 1, color='r')

# %%
clicks = librosa.clicks(beat_times, sr, length=len(x))
ipd.Audio(x + clicks, rate=sr)
# Out:
# C:\Users\dipte\AppData\Local\Temp\ipykernel_22796\4129833394.py:1: FutureWarning: Pass times=[0.         0.62693878 1.25387755 1.88081633 2.5077551  3.13469388
#  3.76163265 4.38857143], frames=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   clicks = librosa.clicks(beat_times, sr, length=len(x))
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(numpy.vstack[x,clicks],rate=sr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 ipd.Audio(numpy.vstack[x,clicks],rate=sr)
#
# TypeError: 'function' object is not subscriptable

# %%
ipd.Audio(numpy.vstack([x, clicks]),rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(tempo)
# Out:
# [95.703125]
