# %%
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plot, IPython.display as disp
import librosa, librosa.display
x,sr=librosa.load("Conga-mono.wav")
disp.Audio(x,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr)
# Out:
# C:\Users\dipte\AppData\Local\Temp\ipykernel_15944\1917055678.py:2: FutureWarning: Pass sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   librosa.display.waveshow(x, sr)

# %%
print(sr)
# Out:
# 22050

# %%
plot.figure(figsize=(15,6))
librosa.display.waveshow(x,rate=22050)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 plot.figure(figsize=(15,6))
# ----> 2 librosa.display.waveshow(x,rate=22050)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\display.py:1468, in waveshow(y, sr, max_points, x_axis, offset, marker, where, label, ax, **kwargs)
# ...

# %%
plot.figure(figsize=(15, 6))
librosa.display.waveshow(x, sr=22050)

# %%
disp.Audio(x,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
onset_frames = librosa.onset.onset_detect(x, sr=sr, wait=1, pre_avg=1, post_avg=1, pre_max=1, post_max=1)
print(onset_frames)
# Out:
# [  7  13  18  25  30  36  43  48  61  66  72  82  88  95 101 107 112 118
#  124 141 149 153 160 166 173 177 183]
# C:\Users\dipte\AppData\Local\Temp\ipykernel_15944\3627481338.py:1: FutureWarning: Pass y=[ 9.8388467e-05 -5.1777592e-05 -1.6167178e-03 ... -5.6765553e-02
#  -7.0570409e-02  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   onset_frames = librosa.onset.onset_detect(x, sr=sr, wait=1, pre_avg=1, post_avg=1, pre_max=1, post_max=1)

# %%
onset_times = librosa.frames_to_time(onset_frames)
print(onset_times)
# Out:
# [0.16253968 0.30185941 0.41795918 0.58049887 0.69659864 0.83591837
#  0.99845805 1.11455782 1.41641723 1.53251701 1.67183673 1.90403628
#  2.04335601 2.20589569 2.34521542 2.48453515 2.60063492 2.73995465
#  2.87927438 3.27401361 3.45977324 3.55265306 3.71519274 3.85451247
#  4.01705215 4.10993197 4.2492517 ]

# %%
S = librosa.stft(x)
logS = librosa.amplitude_to_db(abs(S))

# %%
plt.figure(figsize=(14, 5))
librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='log', cmap='Reds')
plt.vlines(onset_times, 0, 10000, color='#3333FF')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 plt.figure(figsize=(14, 5))
#       2 librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='log', cmap='Reds')
#       3 plt.vlines(onset_times, 0, 10000, color='#3333FF')
#
# NameError: name 'plt' is not defined

# %%
plot.figure(figsize=(14, 5))
librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='log', cmap='Reds')
plot.vlines(onset_times, 0, 10000, color='#3333FF')

# %%
plot.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)
plt.vlines(onset_times, -0.8, 0.79, color='p', alpha=0.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 plot.figure(figsize=(14, 5))
# ----> 2 librosa.display.waveplot(x, sr=sr)
#       3 plt.vlines(onset_times, -0.8, 0.79, color='p', alpha=0.8)
#
# AttributeError: module 'librosa.display' has no attribute 'waveplot'

# %%
plot.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)
plt.vlines(onset_times, -0.8, 0.79, color='p', alpha=0.8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 3>()
#       1 plot.figure(figsize=(14, 5))
#       2 librosa.display.waveshow(x, sr=sr)
# ----> 3 plt.vlines(onset_times, -0.8, 0.79, color='p', alpha=0.8)
#
# NameError: name 'plt' is not defined

# %%
plot.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)
plot.vlines(onset_times, -0.8, 0.79, color='p', alpha=0.8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 plot.figure(figsize=(14, 5))
#       2 librosa.display.waveshow(x, sr=sr)
# ----> 3 plot.vlines(onset_times, -0.8, 0.79, color='p', alpha=0.8)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:3012, in vlines(x, ymin, ymax, colors, linestyles, label, data, **kwargs)
#    3008 @_copy_docstring_and_deprecators(Axes.vlines)
#    3009 def vlines(
#    3010         x, ymin, ymax, colors=None, linestyles='solid', label='', *,
#    3011         data=None, **kwargs):
# -> 3012     return gca().vlines(
#    3013         x, ymin, ymax, colors=colors, linestyles=linestyles,
#    3014         label=label, **({"data": data} if data is not None else {}),
#    3015         **kwargs)
#
# ...

# %%
plot.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)
plot.vlines(onset_times, -0.8, 0.79, color='g', alpha=0.8)

# %%
c=librosa.clicks(frames=onset_frame,sr=sr,length=len(x))
disp.Audio(x+c,rate=sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 c=librosa.clicks(frames=onset_frame,sr=sr,length=len(x))
#       2 disp.Audio(x+c,rate=sr)
#
# NameError: name 'onset_frame' is not defined

# %%
c=librosa.clicks(frames=onset_frames,sr=sr,length=len(x))
disp.Audio(x+c,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy
disp.Audio(numpy.vstack([x, c]), rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
