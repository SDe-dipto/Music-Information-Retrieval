# %%
# %matplotlib inline
from pathlib import Path
import numpy, scipy, matplotlib.pyplot as plt, sklearn, urllib, IPython.display as ipd
import librosa, librosa.display

# %%
kick_sig=[librosa.load(p)[0] for p in Path().glob('Bass_Drum_03_V01.wav')]
snare_signals = [
    librosa.load(p)[0] for p in Path().glob('Snare_05_01.wav')
]

# %%
len(kick_sig)
# Out:
# 1
