# %%
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa
import librosa.display
x,sr=librosa.load('Anry.wav')

# %%
print(x.shape,sr)
plt.figure(figsize=(15,6))
librosa.display.waveshow(x,sr=sr)
# Out:
# (110250,) 22050

# %%
plt.figure(figsize=(14, 5))
librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='log', cmap='Reds')
plt.vlines(onset_times, 0, 10000, color='#3333FF')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 plt.figure(figsize=(14, 5))
# ----> 2 librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='log', cmap='Reds')
#       3 plt.vlines(onset_times, 0, 10000, color='#3333FF')
#
# NameError: name 'logS' is not defined

# %%
S = librosa.stft(x)
logS = librosa.amplitude_to_db(abs(S))
plt.figure(figsize=(14, 5))
librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='log', cmap='Reds')
plt.vlines(onset_times, 0, 10000, color='#3333FF')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       3 plt.figure(figsize=(14, 5))
#       4 librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='log', cmap='Reds')
# ----> 5 plt.vlines(onset_times, 0, 10000, color='#3333FF')
#
# NameError: name 'onset_times' is not defined

# %%
onset_frames = librosa.onset.onset_detect(x, sr=sr, wait=1, pre_avg=1, post_avg=1, pre_max=1, post_max=1)
onset_times = librosa.frames_to_time(onset_frames)
S = librosa.stft(x)
logS = librosa.amplitude_to_db(abs(S))
plt.figure(figsize=(14, 5))
librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='log', cmap='Reds')
plt.vlines(onset_times, 0, 10000, color='#3333FF')
# Out:
# C:\Users\dipte\AppData\Local\Temp\ipykernel_11104\938073626.py:1: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.2171618  -0.22971795
#  -0.28947657] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   onset_frames = librosa.onset.onset_detect(x, sr=sr, wait=1, pre_avg=1, post_avg=1, pre_max=1, post_max=1)

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)
plt.vlines(onset_times, -0.8, 0.79, color='g', alpha=0.8)

# %%
ipd.Audio(x,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
hop_length = 512
frame_length = 1024
rmse = librosa.feature.rmse(x, frame_length=frame_length, hop_length=hop_length).flatten()
rmse_diff = numpy.zeros_like(rmse)
rmse_diff[1:] = numpy.diff(rmse)
print(rmse.shape)
print(rmse_diff.shape)
energy_novelty = numpy.max([numpy.zeros_like(rmse_diff), rmse_diff], axis=0)
frames = numpy.arange(len(rmse))
t = librosa.frames_to_time(frames, sr=sr)
plt.figure(figsize=(15, 6))
plt.plot(t, rmse, 'b--', t, rmse_diff, 'g--^', t, energy_novelty, 'r-')
plt.xlim(0, t.max())
plt.xlabel('Time (sec)')
plt.legend(('RMSE', 'delta RMSE', 'energy novelty'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       1 hop_length = 512
#       2 frame_length = 1024
# ----> 3 rmse = librosa.feature.rmse(x, frame_length=frame_length, hop_length=hop_length).flatten()
#       4 rmse_diff = numpy.zeros_like(rmse)
#       5 rmse_diff[1:] = numpy.diff(rmse)
#
# AttributeError: module 'librosa.feature' has no attribute 'rmse'
